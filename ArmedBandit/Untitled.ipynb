# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
d = np.random.normal(0, 1, 4000)

# %%
count, bins, ignored = plt.hist(d,30)

# %%
sigma = 1
mu = 0

# %%
plt.plot(bins,1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ))

# %%
np.random.normal(0,1,10)
# Out:
# array([-0.12617775,  0.9482221 , -1.11039773,  0.6618548 ,  0.32499324,
#        -1.4163241 , -0.54326624,  1.14861608, -1.91857672, -0.96816985])

# %%
def get_pdf(self, mu, sigma):
        return (1.0 / (self.stdev * math.sqrt(2*math.pi))) * math.exp(-0.5*((x - self.mean) / self.stdev) ** 2)

# %%
np.random.uniform(0.0, 1.0)
# Out:
# 0.48415963571037046

# %%
np.floor(2.222)
# Out:
# 2.0

# %%
from TestBed import TestBed
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

# %%
testBed = TestBed(50, 1000)
r = testBed.run_experiment()[49]
# Out:
# Run # 49

# %%
testBed.agent.Q
# Out:
# array([ 0.02006237, -0.10200657,  0.03381911,  0.11743425])

# %%
testBed.env.Q_Optimal
# Out:
# array([ 0.62520071, -2.54410602, -0.45835222,  0.54963129])

# %%
plt.plot(r)
plt.show()
